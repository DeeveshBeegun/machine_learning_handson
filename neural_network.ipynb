# %% [markdown]
# <a href="https://colab.research.google.com/github/DeeveshBeegun/machine_learning_handson/blob/main/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Input Data

# %%
import kagglehub

path = kagglehub.dataset_download("arshid/iris-flower-dataset")
print("Path to dataset files: ", path)
# Out:
# Using Colab cache for faster access to the 'iris-flower-dataset' dataset.
# Path to dataset files:  /kaggle/input/iris-flower-dataset

# %% [markdown]
# Activation Function

# %%
def sigmoid(z):
  return 1 / (1 + np.exp(-z))

# %% [markdown]
# Network Architecutre

# %%
input_size = 2
hidden_size = 4
output_size = 1

# %% [markdown]
# Initialize weights and biases

# %%
np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))

W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

# %% [markdown]
# Forward Propagation

# %%
z1 = X @ W1 + b1
a1 = sigmoid(z1)

z2 = a1 @ W2 + b2
output = sigmoid(z2)


print("Network output:")
print(output)
